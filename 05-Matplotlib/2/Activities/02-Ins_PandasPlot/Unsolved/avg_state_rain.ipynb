# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1dacfd19978>,
#   <matplotlib.axis.XTick at 0x1dacfd19208>,
#   <matplotlib.axis.XTick at 0x1dacfd190b8>,
#   <matplotlib.axis.XTick at 0x1dad0291a90>,
#   <matplotlib.axis.XTick at 0x1dad0291f60>,
#   <matplotlib.axis.XTick at 0x1dad0291f28>,
#   <matplotlib.axis.XTick at 0x1dad02a46d8>,
#   <matplotlib.axis.XTick at 0x1dad02a4be0>,
#   <matplotlib.axis.XTick at 0x1dad02ab160>,
#   <matplotlib.axis.XTick at 0x1dad02ab630>,
#   <matplotlib.axis.XTick at 0x1dad02abb38>,
#   <matplotlib.axis.XTick at 0x1dad02b30f0>,
#   <matplotlib.axis.XTick at 0x1dad02b3588>,
#   <matplotlib.axis.XTick at 0x1dad02b3a90>,
#   <matplotlib.axis.XTick at 0x1dad02b3e80>,
#   <matplotlib.axis.XTick at 0x1dad02abc18>,
#   <matplotlib.axis.XTick at 0x1dad02a49e8>,
#   <matplotlib.axis.XTick at 0x1dad02bb400>,
#   <matplotlib.axis.XTick at 0x1dad02bb908>,
#   <matplotlib.axis.XTick at 0x1dad02bbe10>,
#   <matplotlib.axis.XTick at 0x1dad02c2358>,
#   <matplotlib.axis.XTick at 0x1dad02c2860>,
#   <matplotlib.axis.XTick at 0x1dad02c2d68>,
#   <matplotlib.axis.XTick at 0x1dad02ca2b0>,
#   <matplotlib.axis.XTick at 0x1dad02c22b0>,
#   <matplotlib.axis.XTick at 0x1dad02a4630>,
#   <matplotlib.axis.XTick at 0x1dad02ca5f8>,
#   <matplotlib.axis.XTick at 0x1dad02cab00>,
#   <matplotlib.axis.XTick at 0x1dad02d30b8>,
#   <matplotlib.axis.XTick at 0x1dad02d3550>,
#   <matplotlib.axis.XTick at 0x1dad02d3a58>,
#   <matplotlib.axis.XTick at 0x1dad02d3f60>,
#   <matplotlib.axis.XTick at 0x1dad02da4a8>,
#   <matplotlib.axis.XTick at 0x1dad02d3f28>,
#   <matplotlib.axis.XTick at 0x1dad02ca4e0>,
#   <matplotlib.axis.XTick at 0x1dad02da550>,
#   <matplotlib.axis.XTick at 0x1dad02dacf8>,
#   <matplotlib.axis.XTick at 0x1dad02e4240>,
#   <matplotlib.axis.XTick at 0x1dad02e4748>,
#   <matplotlib.axis.XTick at 0x1dad02e4c50>,
#   <matplotlib.axis.XTick at 0x1dad02ec198>,
#   <matplotlib.axis.XTick at 0x1dad02ec6a0>,
#   <matplotlib.axis.XTick at 0x1dad02e46a0>,
#   <matplotlib.axis.XTick at 0x1dad02dab00>,
#   <matplotlib.axis.XTick at 0x1dad02ec940>,
#   <matplotlib.axis.XTick at 0x1dad02ec240>,
#   <matplotlib.axis.XTick at 0x1dad02f4518>,
#   <matplotlib.axis.XTick at 0x1dad02f4a20>,
#   <matplotlib.axis.XTick at 0x1dad02f4f28>,
#   <matplotlib.axis.XTick at 0x1dad02fb470>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.700000000000003)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0,0.5,'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()
