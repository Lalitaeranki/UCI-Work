# %%
# New Dependency
from datetime import datetime

# %%
# Dependencies
import tweepy
import json
import numpy as np
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
target_user = 'latimes'

# Get all tweets from home feed
public_tweets = api.user_timeline(target_user)
public_tweets
# Out:
# [{'created_at': 'Sat Sep 22 06:05:03 +0000 2018',
#   'id': 1043380637355438080,
#   'id_str': '1043380637355438080',
#   'text': 'This summer had sweltering heat waves and destructive wildfires. But it also claimed another distinction: the summe… https://t.co/Pz4HPP43vI',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/Pz4HPP43vI',
#      'expanded_url': 'https://twitter.com/i/web/status/1043380637355438080',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 62,
#   'favorite_count': 71,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 04:05:04 +0000 2018',
#   'id': 1043350442728714240,
#   'id_str': '1043350442728714240',
#   'text': 'Yes, California has a full-on fall. And the Sierra is starting to pop already. https://t.co/t2MtaxqeUS https://t.co/G03KPusIZ8',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/t2MtaxqeUS',
#      'expanded_url': 'https://lat.ms/2O8ivUh',
#      'display_url': 'lat.ms/2O8ivUh',
#      'indices': [79, 102]}],
#    'media': [{'id': 1043350440358830080,
#      'id_str': '1043350440358830080',
#      'indices': [103, 126],
#      'media_url': 'http://pbs.twimg.com/media/Dnq5spXV4AADeQO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Dnq5spXV4AADeQO.jpg',
#      'url': 'https://t.co/G03KPusIZ8',
#      'display_url': 'pic.twitter.com/G03KPusIZ8',
#      'expanded_url': 'https://twitter.com/latimes/status/1043350442728714240/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1400, 'h': 788, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1043350440358830080,
#      'id_str': '1043350440358830080',
#      'indices': [103, 126],
#      'media_url': 'http://pbs.twimg.com/media/Dnq5spXV4AADeQO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Dnq5spXV4AADeQO.jpg',
#      'url': 'https://t.co/G03KPusIZ8',
#      'display_url': 'pic.twitter.com/G03KPusIZ8',
#      'expanded_url': 'https://twitter.com/latimes/status/1043350442728714240/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1400, 'h': 788, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}}},
#     {'id': 1043350440350339072,
#      'id_str': '1043350440350339072',
#      'indices': [103, 126],
#      'media_url': 'http://pbs.twimg.com/media/Dnq5spVUUAA7y7S.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Dnq5spVUUAA7y7S.jpg',
#      'url': 'https://t.co/G03KPusIZ8',
#      'display_url': 'pic.twitter.com/G03KPusIZ8',
#      'expanded_url': 'https://twitter.com/latimes/status/1043350442728714240/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1400, 'h': 788, 'resize': 'fit'}}},
#     {'id': 1043350440576864256,
#      'id_str': '1043350440576864256',
#      'indices': [103, 126],
#      'media_url': 'http://pbs.twimg.com/media/Dnq5sqLU0AAPf4g.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Dnq5sqLU0AAPf4g.jpg',
#      'url': 'https://t.co/G03KPusIZ8',
#      'display_url': 'pic.twitter.com/G03KPusIZ8',
#      'expanded_url': 'https://twitter.com/latimes/status/1043350442728714240/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1400, 'h': 787, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 382, 'resize': 'fit'}}}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 172,
#   'favorite_count': 671,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 03:35:04 +0000 2018',
#   'id': 1043342890330673153,
#   'id_str': '1043342890330673153',
#   'text': 'At a time when Kavanaugh’s nomination hangs by a thread, Trump has intervened in a clumsy way that complicates his… https://t.co/7wSVg9cIGp',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/7wSVg9cIGp',
#      'expanded_url': 'https://twitter.com/i/web/status/1043342890330673153',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 24,
#   'favorite_count': 84,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 03:05:03 +0000 2018',
#   'id': 1043335338926718976,
#   'id_str': '1043335338926718976',
#   'text': 'Taiwan authorities have arrested and jailed the owner of a Texas company that sells blueprints for untraceable 3-D-… https://t.co/cQESISmjex',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/cQESISmjex',
#      'expanded_url': 'https://twitter.com/i/web/status/1043335338926718976',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 73,
#   'favorite_count': 133,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 02:35:03 +0000 2018',
#   'id': 1043327788588167168,
#   'id_str': '1043327788588167168',
#   'text': "It's a good time to work in the fake-handbag business.\n\nThe shadow industry — already a big moneymaker — stands to… https://t.co/FTbU2DT0KZ",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/FTbU2DT0KZ',
#      'expanded_url': 'https://twitter.com/i/web/status/1043327788588167168',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 18,
#   'favorite_count': 25,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 02:05:03 +0000 2018',
#   'id': 1043320237880426496,
#   'id_str': '1043320237880426496',
#   'text': 'The state of Indiana is planning to ask the Supreme Court to settle an abortion dispute involving a state law that… https://t.co/r7zpTjPjQh',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/r7zpTjPjQh',
#      'expanded_url': 'https://twitter.com/i/web/status/1043320237880426496',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 39,
#   'favorite_count': 33,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 01:50:03 +0000 2018',
#   'id': 1043316462067347456,
#   'id_str': '1043316462067347456',
#   'text': 'The man killed under the Santa Monica Pier was sleeping after fishing trip, not homeless, his family says https://t.co/uKBxuOmK8J',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/uKBxuOmK8J',
#      'expanded_url': 'https://lat.ms/2psCgHS',
#      'display_url': 'lat.ms/2psCgHS',
#      'indices': [106, 129]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 27,
#   'favorite_count': 32,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 01:35:03 +0000 2018',
#   'id': 1043312690884751360,
#   'id_str': '1043312690884751360',
#   'text': 'After years of dramatic increases, rents are finally showing signs of slowing down across Southern California and t… https://t.co/sZ0uPNw7ZF',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/sZ0uPNw7ZF',
#      'expanded_url': 'https://twitter.com/i/web/status/1043312690884751360',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 27,
#   'favorite_count': 49,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 01:17:04 +0000 2018',
#   'id': 1043308165067157504,
#   'id_str': '1043308165067157504',
#   'text': 'This Mexican American high school soccer team in Salinas, Calif., is a perennial state championship contender. But… https://t.co/YkKet2r7HH',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/YkKet2r7HH',
#      'expanded_url': 'https://twitter.com/i/web/status/1043308165067157504',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 25,
#   'favorite_count': 61,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 01:05:05 +0000 2018',
#   'id': 1043305146476838912,
#   'id_str': '1043305146476838912',
#   'text': 'Small businesses around the country are bracing for the latest round of tariffs, which could cut into already thin… https://t.co/loif0zwRri',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/loif0zwRri',
#      'expanded_url': 'https://twitter.com/i/web/status/1043305146476838912',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 32,
#   'favorite_count': 25,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 00:50:03 +0000 2018',
#   'id': 1043301364942753792,
#   'id_str': '1043301364942753792',
#   'text': 'U.S. Olympic Committee leaders voted Friday to give Paralympic medal winners the same payout that goes to their cou… https://t.co/zPSSUOn5L4',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/zPSSUOn5L4',
#      'expanded_url': 'https://twitter.com/i/web/status/1043301364942753792',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 45,
#   'favorite_count': 160,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 00:35:04 +0000 2018',
#   'id': 1043297592459898880,
#   'id_str': '1043297592459898880',
#   'text': 'It’s easier – and cheaper – than ever to get straighter teeth. Orthodontists think that’s a big problem. https://t.co/XamcxFhZ3I',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/XamcxFhZ3I',
#      'expanded_url': 'https://lat.ms/2xDsk25',
#      'display_url': 'lat.ms/2xDsk25',
#      'indices': [105, 128]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 22,
#   'favorite_count': 52,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Sep 22 00:05:07 +0000 2018',
#   'id': 1043290055975084034,
#   'id_str': '1043290055975084034',
#   'text': 'Southern Californians might remember the summer of 2018 for its sweltering heat waves, record ocean temperatures an… https://t.co/K9sRnCoNXJ',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/K9sRnCoNXJ',
#      'expanded_url': 'https://twitter.com/i/web/status/1043290055975084034',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 74,
#   'favorite_count': 113,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Sep 21 23:35:05 +0000 2018',
#   'id': 1043282496681652224,
#   'id_str': '1043282496681652224',
#   'text': 'Consumers can now freeze their credit for free under a new federal law. https://t.co/XMWYbPoqSA',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/XMWYbPoqSA',
#      'expanded_url': 'https://lat.ms/2puKOy6',
#      'display_url': 'lat.ms/2puKOy6',
#      'indices': [72, 95]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 40,
#   'favorite_count': 53,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Sep 21 23:05:06 +0000 2018',
#   'id': 1043274953964089344,
#   'id_str': '1043274953964089344',
#   'text': 'Fliers who pick Alaska Airlines\' "saver fares" will board last, their seating will be in the back of the plane — mo… https://t.co/c0JFGSAnZM',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/c0JFGSAnZM',
#      'expanded_url': 'https://twitter.com/i/web/status/1043274953964089344',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
# ...
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 13,
#   'favorite_count': 18,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Sep 21 22:35:03 +0000 2018',
#   'id': 1043267391373934592,
#   'id_str': '1043267391373934592',
#   'text': "Do Gavin Newsom and John Cox even want the same job? Their visions of California's governorship radically differ: https://t.co/NK7TgzNoWT",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/NK7TgzNoWT',
#      'expanded_url': 'https://lat.ms/2O0j2qV',
#      'display_url': 'lat.ms/2O0j2qV',
#      'indices': [114, 137]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 14,
#   'favorite_count': 17,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Sep 21 22:05:10 +0000 2018',
#   'id': 1043259868466040832,
#   'id_str': '1043259868466040832',
#   'text': 'Alberto Medina, 25, was found guilty of murder, arson, burglary and animal cruelty in connection with the death of… https://t.co/5HYNqqNW8b',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/5HYNqqNW8b',
#      'expanded_url': 'https://twitter.com/i/web/status/1043259868466040832',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 14,
#   'favorite_count': 39,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Sep 21 21:35:04 +0000 2018',
#   'id': 1043252296208052226,
#   'id_str': '1043252296208052226',
#   'text': 'The Prospector Pete statue at Cal State Long Beach will be relocated to a less prominent place on campus as the uni… https://t.co/nTBWXCG9vN',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/nTBWXCG9vN',
#      'expanded_url': 'https://twitter.com/i/web/status/1043252296208052226',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 33,
#   'favorite_count': 42,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Sep 21 21:20:07 +0000 2018',
#   'id': 1043248534131236864,
#   'id_str': '1043248534131236864',
#   'text': 'Gov. Jerry Brown has ordered an audit of the DMV in response to the public outcry over hours-long wait times and re… https://t.co/LQ7s11SCPC',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/LQ7s11SCPC',
#      'expanded_url': 'https://twitter.com/i/web/status/1043248534131236864',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 50,
#   'favorite_count': 128,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Sep 21 21:05:12 +0000 2018',
#   'id': 1043244780745093121,
#   'id_str': '1043244780745093121',
#   'text': 'In 2014, Dr. Grant Robicheaux appeared on the Bravo show “Online Dating Rituals of the American Male." He\'s now fac… https://t.co/HAJSmEBihv',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/HAJSmEBihv',
#      'expanded_url': 'https://twitter.com/i/web/status/1043244780745093121',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16664681,
#    'id_str': '16664681',
#    'name': 'Los Angeles Times',
#    'screen_name': 'latimes',
#    'location': 'Los Angeles, CA',
#    'description': 'News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.',
#    'url': 'http://t.co/JvbZRDfNzf',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/JvbZRDfNzf',
#        'expanded_url': 'http://latimes.com/',
#        'display_url': 'latimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'http://t.co/zb8HyvYyAJ',
#        'expanded_url': 'http://latimes.com',
#        'display_url': 'latimes.com',
#        'indices': [48, 70]}]}},
#    'protected': False,
#    'followers_count': 3265570,
#    'friends_count': 8425,
#    'listed_count': 31093,
#    'created_at': 'Thu Oct 09 11:07:42 +0000 2008',
#    'favourites_count': 1879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 203980,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043205431340892160/uvDP6wTZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1402448809',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '615F61',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 28,
#   'favorite_count': 25,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %%
# Target User
target_user = 'latimes'

# Get all tweets from home feed
public_tweets = api.user_timeline(target_user)

# A list to hold tweet timestamps
tweet_stamps = []

# Loop through all tweets
for tweet in public_tweets:
    raw_time = tweet["created_at"]
    print(raw_time)
    tweet_stamps.append(raw_time)
# Out:
# Sat Sep 22 06:05:03 +0000 2018
# Sat Sep 22 04:05:04 +0000 2018
# Sat Sep 22 03:35:04 +0000 2018
# Sat Sep 22 03:05:03 +0000 2018
# Sat Sep 22 02:35:03 +0000 2018
# Sat Sep 22 02:05:03 +0000 2018
# Sat Sep 22 01:50:03 +0000 2018
# Sat Sep 22 01:35:03 +0000 2018
# Sat Sep 22 01:17:04 +0000 2018
# Sat Sep 22 01:05:05 +0000 2018
# Sat Sep 22 00:50:03 +0000 2018
# Sat Sep 22 00:35:04 +0000 2018
# Sat Sep 22 00:05:07 +0000 2018
# Fri Sep 21 23:35:05 +0000 2018
# Fri Sep 21 23:05:06 +0000 2018
# Fri Sep 21 22:35:03 +0000 2018
# Fri Sep 21 22:05:10 +0000 2018
# Fri Sep 21 21:35:04 +0000 2018
# Fri Sep 21 21:20:07 +0000 2018
# Fri Sep 21 21:05:12 +0000 2018

# %%
# Convert tweet timestamps to datetime objects that can be manipulated by
# Python
converted_timestamps = []
for raw_time in tweet_stamps:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    # http://strftime.org/
    # YOUR CODE HERE
    converted_time=datetime.strptime(raw_time,"%a %b %d %H:%M:%S %z %Y")
    converted_timestamps.append(converted_time)

# %%
print(tweet_stamps[0])
print(tweet_stamps[1])
# Out:
# Sat Sep 22 06:05:03 +0000 2018
# Sat Sep 22 04:05:04 +0000 2018

# %%
print(converted_timestamps[0])
print(converted_timestamps[1])
# Out:
# 2018-09-22 06:05:03+00:00
# 2018-09-22 04:05:04+00:00

# %%
# Calculate the time difference in seconds
# YOUR CODE HERE
diff = converted_timestamps[0] - converted_timestamps[1]
print("Time difference: ", diff)
print('seconds: {}'.format(diff.seconds))
# Out:
# Time difference:  1:59:59
# seconds: 7199

# %%
converted_length = len(converted_timestamps)
print(f"length of converted timestamps list: {converted_length}")

time_diffs = []

for x in range(converted_length - 1):
    time_diff=converted_timestamps[x]-converted_timestamps[x+1]
    time_diff=time_diff.seconds/3600
    time_diffs.append(time_diff)
    
    # YOUR CODE HERE

print(f"Avg. Hours Between Tweets: {np.mean(time_diffs)}")
# Out:
# length of converted timestamps list: 20
# Avg. Hours Between Tweets: 0.4735526315789475
