# %%
# Dependencies
import tweepy
import json
import pandas as pd
from config import consumer_key, consumer_secret, access_token, access_token_secret
# Your Twitter API Keys


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
api.get_user('katyperry')
# Out:
# {'id': 21447363,
#  'id_str': '21447363',
#  'name': 'KATY PERRY',
#  'screen_name': 'katyperry',
#  'location': '',
#  'profile_location': None,
#  'description': 'Love. Light.',
#  'url': 'https://t.co/UCVo8NkmAc',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/UCVo8NkmAc',
#      'expanded_url': 'http://www.katyperry.com/tour',
#      'display_url': 'katyperry.com/tour',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 106966270,
#  'friends_count': 216,
#  'listed_count': 141278,
#  'created_at': 'Fri Feb 20 23:45:56 +0000 2009',
#  'favourites_count': 6037,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 9260,
#  'lang': 'en',
#  'status': {'created_at': 'Mon Sep 17 22:51:15 +0000 2018',
#   'id': 1041821914430402560,
#   'id_str': '1041821914430402560',
#   'text': 'At that my friends is the cherry on top of a wonderful era. I see you and I love you ❤️\U0001f9e1💛💚💙😴 @ KAABOO Del Mar https://t.co/DxTiRbjihJ',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/DxTiRbjihJ',
#      'expanded_url': 'https://www.instagram.com/p/Bn2DnEBlpz9/?utm_source=ig_twitter_share&igshid=t5z09jcuikrp',
#      'display_url': 'instagram.com/p/Bn2DnEBlpz9/…',
#      'indices': [110, 133]}]},
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1110,
#   'favorite_count': 8418,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': True,
#  'profile_background_color': 'CECFBC',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1001159499133149184/mNHEcMbf_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1001159499133149184/mNHEcMbf_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21447363/1535126308',
#  'profile_link_color': 'D55732',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': '78C0A8',
#  'profile_text_color': '5E412F',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'regular'}

# %%
# Import CSV file into Data Frame
popular_tweeters = pd.read_csv("../Resources/PopularAccounts.csv", dtype=str)

# Iterate through DataFrame
for index, row in popular_tweeters.iterrows():
    
    # Error handling
    try:
        # Grab the username
        
        target_user = row["Screen Name"]
        
        
        # print(target_user)

        # Use the username with the Twitter API get_user
        user_account = api.get_user(target_user)
        user_real_name = user_account["name"]

        # Get the specific column data
        user_tweets = user_account["statuses_count"]
        followers_count = user_account["followers_count"]
        friends_count = user_account["friends_count"]
        favourites_count = user_account["favourites_count"]
        
        # Do the same for "followers_count", "friends_count", and "favourites_count"

        # Replace the row information for each
        popular_tweeters.at[index, "Real Name"] = user_real_name
        popular_tweeters.at[index,"Tweets"]=user_tweets
        popular_tweeters.at[index,"Followers"]=followers_count
        popular_tweeters.at[index,"Following"]=friends_count
        popular_tweeters.at[index,"Favorites Count"]=favourites_count
        # Do the same for "Tweets", "Followers", "Following, and "Favorites Count"
    
    # If an error is encountered, move on with the next iteration of the loop
    except tweepy.TweepError as e:
        print(f"exception for {row['Screen Name']}: {e}")
        popular_tweeters.drop(index=index,inplace=True)
    
        
        
# Export the new CSV as "PopularAccounts_New.csv"

# Hint: use the to.csv() method
popular_tweeters.to_csv("PopularAccounts_New.csv",encoding='utf-8',index=False)
    
# View the DataFrame

popular_tweeters.head()
# Out:
#      Screen Name      Real Name Tweets  Followers Following Favorites Count
# 0      katyperry     KATY PERRY   9260  106966034       216            6037
# 1   justinbieber  Justin Bieber  30540  104428879    304681            3406
# 2    BarackObama   Barack Obama  15525  102291712    619079              11
# 3  Taylorswift13   Taylor Swift    100   83350116         0             464
# 4        rihanna        Rihanna  10178   87563934      1105            1004

# %%
# Calculate Averages of the following: "Tweets"; "Followers"; "Follwing"; "Favorites Count"
# See "Create DataFrame" below for the variable names you should use
average_tweet_count = popular_tweeters["Tweets"].mean()
average_followers=popular_tweeters["Followers"].mean()
average_following_count=popular_tweeters['Following'].mean()
average_favorites_count=popular_tweeters['Favorites Count'].mean()



# Create DataFrame
averages = {"Average Tweet Count": average_tweet_count, 
            "Average Follower Count": average_followers, 
            "Average Following Count": average_following_count,
            "Average Favorites Count": average_favorites_count}

# Create a Dataframe of the averages
pd.DataFrame(averages,index=[0])
# Out:
#    Average Tweet Count  Average Follower Count  Average Following Count  \
# 0             33262.72             49426912.54                 31516.34
#
#    Average Favorites Count
# 0                  1920.76
