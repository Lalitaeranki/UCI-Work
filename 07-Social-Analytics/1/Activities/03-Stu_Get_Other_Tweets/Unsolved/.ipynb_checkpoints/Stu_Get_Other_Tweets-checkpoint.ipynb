# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
var_name="sherryjystad5"

# %%
# Get all tweets from home feed
public_tweets=api.user_timeline(var_name)

# %%
# Loop through all tweets
for tweet in public_tweets:
    print(json.dumps(public_tweets,sort_keys=True, indent=2))
# Out:
# [
#   {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 21 02:15:05 +0000 2018",
#     "entities": {
#       "hashtags": [],
#       "media": [
#         {
#           "display_url": "pic.twitter.com/AK8JVVT4QF",
#           "expanded_url": "https://twitter.com/sherryjystad5/status/1042960375249924096/photo/1",
#           "id": 1042960370057408512,
#           "id_str": "1042960370057408512",
#           "indices": [
#             41,
#             64
#           ],
#           "media_url": "http://pbs.twimg.com/tweet_video_thumb/DnlW7kQU8AAdvmD.jpg",
#           "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DnlW7kQU8AAdvmD.jpg",
#           "sizes": {
#             "large": {
#               "h": 216,
#               "resize": "fit",
#               "w": 500
#             },
#             "medium": {
#               "h": 216,
#               "resize": "fit",
#               "w": 500
#             },
#             "small": {
#               "h": 216,
#               "resize": "fit",
#               "w": 500
#             },
#             "thumb": {
#               "h": 150,
#               "resize": "crop",
#               "w": 150
#             }
#           },
#           "type": "photo",
#           "url": "https://t.co/AK8JVVT4QF"
#         }
#       ],
#       "symbols": [],
#       "urls": [],
#       "user_mentions": []
#     },
#     "extended_entities": {
#       "media": [
#         {
#           "display_url": "pic.twitter.com/AK8JVVT4QF",
#           "expanded_url": "https://twitter.com/sherryjystad5/status/1042960375249924096/photo/1",
#           "id": 1042960370057408512,
#           "id_str": "1042960370057408512",
#           "indices": [
#             41,
#             64
#           ],
#           "media_url": "http://pbs.twimg.com/tweet_video_thumb/DnlW7kQU8AAdvmD.jpg",
#           "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DnlW7kQU8AAdvmD.jpg",
#           "sizes": {
#             "large": {
#               "h": 216,
#               "resize": "fit",
#               "w": 500
#             },
#             "medium": {
#               "h": 216,
#               "resize": "fit",
#               "w": 500
#             },
#             "small": {
#               "h": 216,
#               "resize": "fit",
#               "w": 500
#             },
#             "thumb": {
#               "h": 150,
#               "resize": "crop",
#               "w": 150
#             }
#           },
#           "type": "animated_gif",
#           "url": "https://t.co/AK8JVVT4QF",
#           "video_info": {
#             "aspect_ratio": [
#               125,
#               54
#             ],
#             "variants": [
#               {
#                 "bitrate": 0,
#                 "content_type": "video/mp4",
#                 "url": "https://video.twimg.com/tweet_video/DnlW7kQU8AAdvmD.mp4"
#               }
#             ]
#           }
#         }
#       ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1042960375249924096,
#     "id_str": "1042960375249924096",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "text": "I have no life because of databoot camp. https://t.co/AK8JVVT4QF",
#     "truncated": false,
#     "user": {
#       "contributors_enabled": false,
#       "created_at": "Thu Aug 23 18:21:19 +0000 2018",
#       "default_profile": true,
#       "default_profile_image": true,
#       "description": "",
#       "entities": {
#         "description": {
#           "urls": []
#         }
#       },
#       "favourites_count": 0,
#       "follow_request_sent": false,
#       "followers_count": 3,
#       "following": false,
#       "friends_count": 2,
#       "geo_enabled": false,
#       "has_extended_profile": false,
#       "id": 1032694285798277122,
#       "id_str": "1032694285798277122",
#       "is_translation_enabled": false,
#       "is_translator": false,
#       "lang": "en",
#       "listed_count": 0,
#       "location": "",
#       "name": "sherryjystad5",
#       "notifications": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": null,
#       "profile_background_image_url_https": null,
#       "profile_background_tile": false,
#       "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#       "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "protected": false,
#       "screen_name": "sherryjystad5",
#       "statuses_count": 1,
#       "time_zone": null,
#       "translator_type": "none",
#       "url": null,
#       "utc_offset": null,
#       "verified": false
#     }
#   }
# ]
