# %%
# Dependencies
import tweepy
import json
from config import (consumer_key, consumer_secret,
                    access_token, access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User Account
target_user = "@TheStressGuys"
tweet_times=[]
# Counter
counter = 0

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(1, 6):

    # Get all tweets from home feed
    
    
    # YOUR CODE HERE
    public_tweets=api.user_timeline(target_user,page=x)
    for tweet in public_tweets:
        tweet_times.append(tweet['text'])
      
        counter += 1
        
        # Print tweets for preview
        if counter % 100 == 0:
            print(tweet_times)

    
    # Loop through all tweets and print the tweet text
    # YOUR CODE HERE
    print(len(tweet_times))
# Out:
# 20
# 40
# 60
# 80
# ['How Stress Affects Children (And What Parents Can do About\xa0It) https://t.co/SiITMdx6Cp https://t.co/wDc4PDCD3G', 'Tibetan Singing Bowl Buying\xa0Guide https://t.co/yFS9wbHrWc https://t.co/weS1wyo36Y', '10 Best Meditation Books of\xa02018 https://t.co/MXzGA5h5vH https://t.co/HJ9gcV86a7', '10 Best Guided Journals To Make 2018 Your\xa0Year https://t.co/dkJKPvUGEu https://t.co/C7mjDOdJQE', 'The 10 Best Meditation Apps of\xa02018 https://t.co/zCh29dJHv2 https://t.co/0S58pTP8Xs', '17 Common Signs Of Stress You’re Probably\xa0Ignoring https://t.co/tzdNKATAjy https://t.co/7kyRMFFUO9', 'How to Deal With Stress: 16 Ways Calm People Handle\xa0Stressors https://t.co/e8rUCdP3G2 https://t.co/5vJYlsXveg', '19 Amazing Journaling Prompts For Self-Discovery In\xa02018 https://t.co/VtuYhDRgtX https://t.co/s59SCKfr5m', '23 Journaling Prompts To Improve Self Esteem In\xa02018 https://t.co/McDm1wXWh2 https://t.co/pZA04P1DNu', 'Aristotle On Happiness: Quotes, Thoughts &amp;\xa0Philosophy https://t.co/CyXGHbY6nS https://t.co/zjYmRSSGHc', 'Do Stress Pills\xa0Work? https://t.co/9ONAGBP12R https://t.co/AMga98nudF', 'Emotional Contagion: Are Moods Really\xa0Contagious? https://t.co/JyO0Yj37W5 https://t.co/OlNy9GR6LD', 'How to Deal With the Stress of a New\xa0Baby https://t.co/1pab0GJAQG https://t.co/v9VnpYA1jD', 'How To Feel Less Stressed: 10 Tips Successful People Swear\xa0By https://t.co/cMZTcdJxIL https://t.co/GQ7KJpoi51', 'How To Overcome OCD Intrusive\xa0Thoughts https://t.co/QpVkB7cpAm https://t.co/QROhQmrgeW', 'Is It Ok To Drink When You’re\xa0Stressed? https://t.co/XERq2cthIl https://t.co/IAY7frTxCj', 'How To Relax Your Mind From Stress (13 Tips to Slow Your\xa0Thoughts) https://t.co/MLWZWSOSv4 https://t.co/H2D8jlQDbq', 'The Effects Of Stress On The Body And\xa0Mind https://t.co/u3vyeKinhD https://t.co/nc4aaWxXqt', 'Top 12 Stressors In Your Life &amp; How To Avoid\xa0Them https://t.co/UP2U4vMHFj https://t.co/Byu0utxNKP', 'The Ultimate Guide To\xa0Journaling https://t.co/twNNLJBcc3 https://t.co/G0Uu4p8QuG', 'What Are The Long Term Effects Of Stress? (17 Symptoms to\xa0Know) https://t.co/WLUmB9fmFC https://t.co/pCGO4PRObd', '8 Benefits Of Mindfulness For Your Mind And Body (Backed By\xa0Science) https://t.co/PlD3K9ScD8 https://t.co/vl64etT2XQ', '16 Best Stress Relieving Hobbies Guaranteed To Make You\xa0Relaxed https://t.co/gUnuFWFPBh https://t.co/IhaIUoo244', '13 Proven Stress Reduction Techniques For Any\xa0Situation https://t.co/8Q7T6OcWC5 https://t.co/rkIxZ7whA5', '12 New Stress Management Strategies You Haven’t Heard\xa0Before https://t.co/v5vCGXVLMY https://t.co/rlXiNfMOaS', '11 Little-Known Benefits Of Journaling For Mental\xa0Health https://t.co/FR4jxxfm9C https://t.co/K2FTS0uq9J', 'How to Stop Stress Nausea &amp; Stress Induced\xa0Vomiting https://t.co/buCfydX9c0 https://t.co/kHvDWbnWmC', 'How to Create a Relaxing Meditation Room At\xa0Home https://t.co/EkXvrDvHF8 https://t.co/zsPaNdEHU4', 'How to Create a Meditation Space for Small\xa0Apartments https://t.co/syL55pcTqr https://t.co/hy5YGoyV8I', 'SI 013: Gratitude https://t.co/Ui1pam99dB https://t.co/KWx9QN9fg1', '8 Ways to Practice Mindful Eating And Get Real\xa0Results https://t.co/qyuyWrala4 https://t.co/dMzYrtXkRn', 'SI 012: Scream\xa0Therapy https://t.co/pkuXuBreIa https://t.co/CpOT6Go8Ot', '6 Ways to Overcome Morning\xa0Anxiety https://t.co/St3iezFRb1 https://t.co/mCyHidRDRK', 'SI 011: Internal vs. External\xa0Stressors https://t.co/WdA852OnnG https://t.co/iiFMJMdMNA', 'Stressed About Your Wedding? 6 Tips for a Stress Free\xa0Wedding https://t.co/ZLrLUtlqJD https://t.co/8O19FEROe9', 'SI 010: Fake\xa0Happiness https://t.co/A8RnOGwAPB https://t.co/j0oJrVzDVJ', 'Stressed About Pregnancy? Here’s What to\xa0Do https://t.co/D0F0dfPz6B https://t.co/ps9Mx5Ncs9', 'SI 009 – People\xa0Pleasing https://t.co/Op9cYSapzW https://t.co/LBEe59GwZC', '10 Unhealthy Ways to Cope With\xa0Stress https://t.co/wF4chwupIr https://t.co/S5NNNzHfm4', 'SI 008 – Foods for\xa0Anxiety https://t.co/0ShwmQUXh7 ht ...
# 100

# %%
public_tweets
# Out:
# [{'created_at': 'Mon Nov 13 13:01:00 +0000 2017',
#   'id': 930057912738861056,
#   'id_str': '930057912738861056',
#   'text': 'How to Be Optimistic: 10 Powerful Habits to Fuel\xa0Optimism https://t.co/sjvC9aBjgg https://t.co/28QvZjGocb',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/sjvC9aBjgg',
#      'expanded_url': 'http://truestressmanagement.com/how-to-be-optimistic/',
#      'display_url': 'truestressmanagement.com/how-to-be-opti…',
#      'indices': [58, 81]}],
#    'media': [{'id': 930057910435979264,
#      'id_str': '930057910435979264',
#      'indices': [82, 105],
#      'media_url': 'http://pbs.twimg.com/media/DOg6vewUIAAdm8K.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DOg6vewUIAAdm8K.jpg',
#      'url': 'https://t.co/28QvZjGocb',
#      'display_url': 'pic.twitter.com/28QvZjGocb',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/930057912738861056/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 354, 'resize': 'fit'},
#       'medium': {'w': 800, 'h': 416, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 930057910435979264,
#      'id_str': '930057910435979264',
#      'indices': [82, 105],
#      'media_url': 'http://pbs.twimg.com/media/DOg6vewUIAAdm8K.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DOg6vewUIAAdm8K.jpg',
#      'url': 'https://t.co/28QvZjGocb',
#      'display_url': 'pic.twitter.com/28QvZjGocb',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/930057912738861056/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 354, 'resize': 'fit'},
#       'medium': {'w': 800, 'h': 416, 'resize': 'fit'}}}]},
#   'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Nov 06 13:01:43 +0000 2017',
#   'id': 927521376977719296,
#   'id_str': '927521376977719296',
#   'text': 'How to Stop Being Pessimistic: 12 Powerful Habits to Kill\xa0Pessimism https://t.co/z696Q3R4XE https://t.co/aAiRAi9Udn',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/z696Q3R4XE',
#      'expanded_url': 'http://truestressmanagement.com/how-to-stop-pessimistic/',
#      'display_url': 'truestressmanagement.com/how-to-stop-pe…',
#      'indices': [68, 91]}],
#    'media': [{'id': 927521374645579777,
#      'id_str': '927521374645579777',
#      'indices': [92, 115],
#      'media_url': 'http://pbs.twimg.com/media/DN83xqlU8AE1cYK.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DN83xqlU8AE1cYK.jpg',
#      'url': 'https://t.co/aAiRAi9Udn',
#      'display_url': 'pic.twitter.com/aAiRAi9Udn',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/927521376977719296/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 354, 'resize': 'fit'},
#       'large': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'medium': {'w': 800, 'h': 416, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 927521374645579777,
#      'id_str': '927521374645579777',
#      'indices': [92, 115],
#      'media_url': 'http://pbs.twimg.com/media/DN83xqlU8AE1cYK.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DN83xqlU8AE1cYK.jpg',
#      'url': 'https://t.co/aAiRAi9Udn',
#      'display_url': 'pic.twitter.com/aAiRAi9Udn',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/927521376977719296/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 354, 'resize': 'fit'},
#       'large': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'medium': {'w': 800, 'h': 416, 'resize': 'fit'}}}]},
#   'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Nov 02 13:31:46 +0000 2017',
#   'id': 926079388415905792,
#   'id_str': '926079388415905792',
#   'text': "Good morning! Don't forget your breakfast!\n📸 @bowlofrachelandrice https://t.co/RFxxZPO7gq https://t.co/d4nECOnjgf",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/RFxxZPO7gq',
#      'expanded_url': 'http://ift.tt/2zZrE6C',
#      'display_url': 'ift.tt/2zZrE6C',
#      'indices': [66, 89]}],
#    'media': [{'id': 926079385500864512,
#      'id_str': '926079385500864512',
#      'indices': [90, 113],
#      'media_url': 'http://pbs.twimg.com/media/DNoYS2aXUAA_bBt.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNoYS2aXUAA_bBt.jpg',
#      'url': 'https://t.co/d4nECOnjgf',
#      'display_url': 'pic.twitter.com/d4nECOnjgf',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/926079388415905792/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 926079385500864512,
#      'id_str': '926079385500864512',
#      'indices': [90, 113],
#      'media_url': 'http://pbs.twimg.com/media/DNoYS2aXUAA_bBt.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNoYS2aXUAA_bBt.jpg',
#      'url': 'https://t.co/d4nECOnjgf',
#      'display_url': 'pic.twitter.com/d4nECOnjgf',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/926079388415905792/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 31 01:53:43 +0000 2017',
#   'id': 925178941400322049,
#   'id_str': '925178941400322049',
#   'text': '13 Tips to Handle Stressful\xa0Relationships https://t.co/rPIlPAYa6e https://t.co/v4LiYhfmCf',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/rPIlPAYa6e',
#      'expanded_url': 'http://truestressmanagement.com/stressful-relationships/',
#      'display_url': 'truestressmanagement.com/stressful-rela…',
#      'indices': [42, 65]}],
#    'media': [{'id': 925178938787119105,
#      'id_str': '925178938787119105',
#      'indices': [66, 89],
#      'media_url': 'http://pbs.twimg.com/media/DNblV9AUQAE5Vqc.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNblV9AUQAE5Vqc.jpg',
#      'url': 'https://t.co/v4LiYhfmCf',
#      'display_url': 'pic.twitter.com/v4LiYhfmCf',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/925178941400322049/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 354, 'resize': 'fit'},
#       'medium': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'large': {'w': 800, 'h': 416, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 925178938787119105,
#      'id_str': '925178938787119105',
#      'indices': [66, 89],
#      'media_url': 'http://pbs.twimg.com/media/DNblV9AUQAE5Vqc.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNblV9AUQAE5Vqc.jpg',
#      'url': 'https://t.co/v4LiYhfmCf',
#      'display_url': 'pic.twitter.com/v4LiYhfmCf',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/925178941400322049/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 354, 'resize': 'fit'},
#       'medium': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'large': {'w': 800, 'h': 416, 'resize': 'fit'}}}]},
#   'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Oct 30 13:38:47 +0000 2017',
#   'id': 924993991287943171,
#   'id_str': '924993991287943171',
#   'text': 'Monday. Breakfast. Health. Keep it simple.\n📸 @realandvibrant https://t.co/Hw5cw3PrA9 https://t.co/W3VrVsVFli',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'realandvibrant',
#      'name': 'Sapana',
#      'id': 734616582605967360,
#      'id_str': '734616582605967360',
#      'indices': [45, 60]}],
#    'urls': [{'url': 'https://t.co/Hw5cw3PrA9',
#      'expanded_url': 'http://ift.tt/2yWhMLz',
#      'display_url': 'ift.tt/2yWhMLz',
#      'indices': [61, 84]}],
#    'media': [{'id': 924993988976955392,
#      'id_str': '924993988976955392',
#      'indices': [85, 108],
#      'media_url': 'http://pbs.twimg.com/media/DNY9IdRX0AAMBAH.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNY9IdRX0AAMBAH.jpg',
#      'url': 'https://t.co/W3VrVsVFli',
#      'display_url': 'pic.twitter.com/W3VrVsVFli',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/924993991287943171/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 924993988976955392,
#      'id_str': '924993988976955392',
#      'indices': [85, 108],
#      'media_url': 'http://pbs.twimg.com/media/DNY9IdRX0AAMBAH.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNY9IdRX0AAMBAH.jpg',
#      'url': 'https://t.co/W3VrVsVFli',
#      'display_url': 'pic.twitter.com/W3VrVsVFli',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/924993991287943171/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Oct 28 15:29:28 +0000 2017',
#   'id': 924297070642593792,
#   'id_str': '924297070642593792',
#   'text': 'Jumping into the weekend like @jordentually https://t.co/7PZ3bI9RcW https://t.co/7hyLrpmOo8',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'JordenTually',
#      'name': 'Jorden Tually',
#      'id': 192400301,
#      'id_str': '192400301',
#      'indices': [30, 43]}],
#    'urls': [{'url': 'https://t.co/7PZ3bI9RcW',
#      'expanded_url': 'http://ift.tt/2gQSsSJ',
#      'display_url': 'ift.tt/2gQSsSJ',
#      'indices': [44, 67]}],
#    'media': [{'id': 924297068130263040,
#      'id_str': '924297068130263040',
#      'indices': [68, 91],
#      'media_url': 'http://pbs.twimg.com/media/DNPDSUzW4AALU2S.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNPDSUzW4AALU2S.jpg',
#      'url': 'https://t.co/7hyLrpmOo8',
#      'display_url': 'pic.twitter.com/7hyLrpmOo8',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/924297070642593792/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 924297068130263040,
#      'id_str': '924297068130263040',
#      'indices': [68, 91],
#      'media_url': 'http://pbs.twimg.com/media/DNPDSUzW4AALU2S.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNPDSUzW4AALU2S.jpg',
#      'url': 'https://t.co/7hyLrpmOo8',
#      'display_url': 'pic.twitter.com/7hyLrpmOo8',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/924297070642593792/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Oct 27 12:37:26 +0000 2017',
#   'id': 923891388827217920,
#   'id_str': '923891388827217920',
#   'text': "Happy Friday, don't forget to power up with a good breakfast!\n📸 @pastryandtravel https://t.co/kLK9saqrPw https://t.co/mQivu9xJPw",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'pastryandtravel',
#      'name': 'Pastryandtravel',
#      'id': 750592076908269568,
#      'id_str': '750592076908269568',
#      'indices': [64, 80]}],
#    'urls': [{'url': 'https://t.co/kLK9saqrPw',
#      'expanded_url': 'http://ift.tt/2zJvGQo',
#      'display_url': 'ift.tt/2zJvGQo',
#      'indices': [81, 104]}],
#    'media': [{'id': 923891386763698176,
#      'id_str': '923891386763698176',
#      'indices': [105, 128],
#      'media_url': 'http://pbs.twimg.com/media/DNJSUj8X4AA-Pss.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNJSUj8X4AA-Pss.jpg',
#      'url': 'https://t.co/mQivu9xJPw',
#      'display_url': 'pic.twitter.com/mQivu9xJPw',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/923891388827217920/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 923891386763698176,
#      'id_str': '923891386763698176',
#      'indices': [105, 128],
#      'media_url': 'http://pbs.twimg.com/media/DNJSUj8X4AA-Pss.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DNJSUj8X4AA-Pss.jpg',
#      'url': 'https://t.co/mQivu9xJPw',
#      'display_url': 'pic.twitter.com/mQivu9xJPw',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/923891388827217920/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 25 13:34:12 +0000 2017',
#   'id': 923180896781586432,
#   'id_str': '923180896781586432',
#   'text': "Jump for joy, we've made it to Hump Day! The weekend is right around the corner, what do you have planned?\n.\n.\n📸 @…… https://t.co/8Ym2qvj7pY",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/8Ym2qvj7pY',
#      'expanded_url': 'https://twitter.com/i/web/status/923180896781586432',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 24 13:35:44 +0000 2017',
#   'id': 922818895324614656,
#   'id_str': '922818895324614656',
#   'text': "You can thrive anywhere. Don't let your circumstances determine your level of success.\n.\n.\n📸 @veggiekins… https://t.co/O6tjEtdgMD",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'veggiekins',
#      'name': 'Christina Richardson',
#      'id': 21443379,
#      'id_str': '21443379',
#      'indices': [93, 104]}],
#    'urls': [{'url': 'https://t.co/O6tjEtdgMD',
#      'expanded_url': 'https://twitter.com/i/web/status/922818895324614656',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [106, 129]}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Oct 23 13:33:49 +0000 2017',
#   'id': 922456025629974528,
#   'id_str': '922456025629974528',
#   'text': 'Just in case you needed a reminder this morning. Happy Monday! https://t.co/xha2J2SUQS https://t.co/3niLsj6cls',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/xha2J2SUQS',
#      'expanded_url': 'http://ift.tt/2zwpo6P',
#      'display_url': 'ift.tt/2zwpo6P',
#      'indices': [63, 86]}],
#    'media': [{'id': 922456023453065216,
#      'id_str': '922456023453065216',
#      'indices': [87, 110],
#      'media_url': 'http://pbs.twimg.com/media/DM043a7W4AAw4n8.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DM043a7W4AAw4n8.jpg',
#      'url': 'https://t.co/3niLsj6cls',
#      'display_url': 'pic.twitter.com/3niLsj6cls',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/922456025629974528/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 640, 'h': 640, 'resize': 'fit'},
#       'small': {'w': 640, 'h': 640, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 640, 'h': 640, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 922456023453065216,
#      'id_str': '922456023453065216',
#      'indices': [87, 110],
#      'media_url': 'http://pbs.twimg.com/media/DM043a7W4AAw4n8.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DM043a7W4AAw4n8.jpg',
#      'url': 'https://t.co/3niLsj6cls',
#      'display_url': 'pic.twitter.com/3niLsj6cls',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/922456025629974528/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 640, 'h': 640, 'resize': 'fit'},
#       'small': {'w': 640, 'h': 640, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 640, 'h': 640, 'resize': 'fit'}}}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Oct 23 12:00:38 +0000 2017',
#   'id': 922432575750238210,
#   'id_str': '922432575750238210',
#   'text': 'How to Boost Your Self-Confidence: 5 Life-Changing\xa0Hacks https://t.co/0hKwJYWqzv https://t.co/bWoNUNYHko',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/0hKwJYWqzv',
#      'expanded_url': 'http://truestressmanagement.com/how-to-boost-self-confidence/',
#      'display_url': 'truestressmanagement.com/how-to-boost-s…',
#      'indices': [57, 80]}],
#    'media': [{'id': 922432573531291648,
#      'id_str': '922432573531291648',
#      'indices': [81, 104],
#      'media_url': 'http://pbs.twimg.com/media/DM0jidKVAAAl0zN.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DM0jidKVAAAl0zN.jpg',
#      'url': 'https://t.co/bWoNUNYHko',
#      'display_url': 'pic.twitter.com/bWoNUNYHko',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/922432575750238210/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 354, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 922432573531291648,
#      'id_str': '922432573531291648',
#      'indices': [81, 104],
#      'media_url': 'http://pbs.twimg.com/media/DM0jidKVAAAl0zN.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DM0jidKVAAAl0zN.jpg',
#      'url': 'https://t.co/bWoNUNYHko',
#      'display_url': 'pic.twitter.com/bWoNUNYHko',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/922432575750238210/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 800, 'h': 416, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 354, 'resize': 'fit'}}}]},
#   'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Oct 21 14:53:42 +0000 2017',
#   'id': 921751351192965125,
#   'id_str': '921751351192965125',
#   'text': "Sometimes you can add to your life by subtracting the things you don't need. #additionbysubtraction… https://t.co/Q4us8YvJt1",
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'additionbysubtraction',
#      'indices': [77, 99]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/Q4us8YvJt1',
#      'expanded_url': 'https://twitter.com/i/web/status/921751351192965125',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [101, 124]}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Oct 20 13:46:29 +0000 2017',
#   'id': 921372050157129728,
#   'id_str': '921372050157129728',
# ...
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Oct 16 14:41:54 +0000 2017',
#   'id': 919936445338603520,
#   'id_str': '919936445338603520',
#   'text': "It's not July, but this quote is still very relevant. It costs nothing to be kind, but being unkind could cost you…… https://t.co/zc1KEnv2x2",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/zc1KEnv2x2',
#      'expanded_url': 'https://twitter.com/i/web/status/919936445338603520',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Oct 16 13:33:30 +0000 2017',
#   'id': 919919231101267969,
#   'id_str': '919919231101267969',
#   'text': "It's not July, but this quote is still very relevant. It costs nothing to be kind, but being unkind could cost you…… https://t.co/RuQ2WowpLY",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/RuQ2WowpLY',
#      'expanded_url': 'https://twitter.com/i/web/status/919919231101267969',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Oct 14 16:09:23 +0000 2017',
#   'id': 919233682782683137,
#   'id_str': '919233682782683137',
#   'text': 'Now this is what you call a dream vacation! https://t.co/SXfi0iqxk6 https://t.co/efUng5HqpA',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/SXfi0iqxk6',
#      'expanded_url': 'http://ift.tt/2yneAKU',
#      'display_url': 'ift.tt/2yneAKU',
#      'indices': [44, 67]}],
#    'media': [{'id': 919233680798879744,
#      'id_str': '919233680798879744',
#      'indices': [68, 91],
#      'media_url': 'http://pbs.twimg.com/media/DMHGKZGXkAAzFiy.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DMHGKZGXkAAzFiy.jpg',
#      'url': 'https://t.co/efUng5HqpA',
#      'display_url': 'pic.twitter.com/efUng5HqpA',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/919233682782683137/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 809, 'h': 809, 'resize': 'fit'},
#       'medium': {'w': 809, 'h': 809, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 919233680798879744,
#      'id_str': '919233680798879744',
#      'indices': [68, 91],
#      'media_url': 'http://pbs.twimg.com/media/DMHGKZGXkAAzFiy.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DMHGKZGXkAAzFiy.jpg',
#      'url': 'https://t.co/efUng5HqpA',
#      'display_url': 'pic.twitter.com/efUng5HqpA',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/919233682782683137/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 809, 'h': 809, 'resize': 'fit'},
#       'medium': {'w': 809, 'h': 809, 'resize': 'fit'}}}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Oct 13 13:39:57 +0000 2017',
#   'id': 918833688829480960,
#   'id_str': '918833688829480960',
#   'text': 'Happy Friday! Tag your yoga partner! https://t.co/gziIUGKJBD https://t.co/gDVT6QPt4r',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/gziIUGKJBD',
#      'expanded_url': 'http://ift.tt/2ykzZ7s',
#      'display_url': 'ift.tt/2ykzZ7s',
#      'indices': [37, 60]}],
#    'media': [{'id': 918833686870708229,
#      'id_str': '918833686870708229',
#      'indices': [61, 84],
#      'media_url': 'http://pbs.twimg.com/media/DMBaXrmXUAUr-ss.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DMBaXrmXUAUr-ss.jpg',
#      'url': 'https://t.co/gDVT6QPt4r',
#      'display_url': 'pic.twitter.com/gDVT6QPt4r',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/918833688829480960/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 918833686870708229,
#      'id_str': '918833686870708229',
#      'indices': [61, 84],
#      'media_url': 'http://pbs.twimg.com/media/DMBaXrmXUAUr-ss.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DMBaXrmXUAUr-ss.jpg',
#      'url': 'https://t.co/gDVT6QPt4r',
#      'display_url': 'pic.twitter.com/gDVT6QPt4r',
#      'expanded_url': 'https://twitter.com/TheStressGuys/status/918833688829480960/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 1024, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 1024, 'resize': 'fit'}}}]},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2392930705,
#    'id_str': '2392930705',
#    'name': 'Stress Management',
#    'screen_name': 'TheStressGuys',
#    'location': '',
#    'description': 'Stress Management Tips. Stop stressing and start living.',
#    'url': 'http://t.co/blaBD3EKCb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/blaBD3EKCb',
#        'expanded_url': 'http://truestressmanagement.com',
#        'display_url': 'truestressmanagement.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 983,
#    'friends_count': 585,
#    'listed_count': 10,
#    'created_at': 'Sun Mar 16 15:59:10 +0000 2014',
#    'favourites_count': 275,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4375,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799444426649206784/9KJa5Aas_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2392930705/1447821680',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]
